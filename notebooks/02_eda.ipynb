# %% [markdown]
# # Exploratory Data Analysis
# Inspect class balance, sample images, and image dimensions.

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
import os

train_path = "dataset/raw/Training"

for cls in os.listdir(train_path):
    print(cls, len(os.listdir(os.path.join(train_path, cls))))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 5
#       1 import os
#       3 train_path = "dataset/raw/Training"
# ----> 5 for cls in os.listdir(train_path):
#       6     print(cls, len(os.listdir(os.path.join(train_path, cls))))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'dataset/raw/Training'

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\ROKITH\OneDrive\사진\문서\Brain Tumor Classification\brain-tumor-detection\notebooks

# %%
import os

print(os.listdir(".."))
# Out:
# ['.git', '.gitignore', 'app.py', 'dataset', 'LICENSE', 'model', 'notebooks', 'README.md', 'requirements.txt', 'screenshots', 'src', 'static', 'templates']

# %%
train_path = "../dataset/raw/Training"

# %%
import os

print(os.path.exists(train_path))
# Out:
# True

# %%
import os

train_path = "../dataset/raw/Training"

for cls in os.listdir(train_path):
    class_path = os.path.join(train_path, cls)
    
    if os.path.isdir(class_path):
        print(f"{cls}: {len(os.listdir(class_path))} images")
# Out:
# glioma: 1400 images
# meningioma: 1400 images
# notumor: 1400 images
# pituitary: 1400 images

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

train_path = "../dataset/raw/Training"

classes = os.listdir(train_path)

plt.figure(figsize=(12, 8))

for i, cls in enumerate(classes[:4]):
    img_name = os.listdir(os.path.join(train_path, cls))[0]
    
    img_path = os.path.join(train_path, cls, img_name)
    
    img = Image.open(img_path)

    plt.subplot(2, 2, i + 1)
    plt.imshow(img)
    plt.title(cls)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import os
import matplotlib.pyplot as plt

train_path = "../dataset/raw/Training"

classes = []
counts = []

for cls in os.listdir(train_path):
    class_path = os.path.join(train_path, cls)

    if os.path.isdir(class_path):
        classes.append(cls)
        counts.append(len(os.listdir(class_path)))

plt.figure(figsize=(8,5))
plt.bar(classes, counts)
plt.title("Class Distribution")
plt.xlabel("Classes")
plt.ylabel("Number of Images")
plt.show()

# %%
# Check image dimensions
import os
from PIL import Image

train_path = "../dataset/raw/Training"

sizes = []

for cls in os.listdir(train_path):
    class_path = os.path.join(train_path, cls)

    for img_name in os.listdir(class_path)[:100]:
        img_path = os.path.join(class_path, img_name)

        img = Image.open(img_path)
        sizes.append(img.size)

print("Unique image sizes:")
print(set(sizes))
# Out:
# Unique image sizes:
# {(416, 512), (630, 630), (350, 350), (420, 280), (234, 224), (405, 484), (442, 442), (275, 301), (393, 400), (208, 278), (442, 454), (236, 236), (232, 217), (173, 201), (200, 252), (512, 512), (201, 251), (230, 235), (212, 238), (215, 234), (236, 220), (626, 686), (208, 242), (256, 256), (441, 442), (470, 432), (196, 257), (497, 398), (359, 449), (900, 741), (216, 293), (201, 250), (192, 192), (236, 366), (236, 250), (339, 415), (428, 417), (354, 443), (468, 444), (194, 259), (642, 361), (236, 213), (150, 198), (227, 262), (538, 548), (528, 528), (504, 540), (225, 225), (262, 244), (275, 183), (235, 244), (218, 234), (218, 231), (236, 252)}
